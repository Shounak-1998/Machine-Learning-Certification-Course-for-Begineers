# %% [markdown]
# ---
#
# <center><h1>📍 📍 SciPy 📍 📍</h1></center>
#
# ---
#
# ***SciPy is a open source scientific library for python. The SciPy library depends on NumPy, which provides convenient and fast N-dimensional array manipulation.***
#
# ---

# %%
# import the scipy library
import scipy
import numpy as np

# %% [markdown]
# ***If you got an error while running the above cell, import it by using the following command***
#
# ***`!pip3 install numpy`***
#
# ---

# %%
# check the version of scipy
scipy.__version__
# Out:
# '1.10.0'

# %% [markdown]
# #### `COMPUTE THE Nth DERIVATE OF A FUNCTION`
#
# ---

# %%
# import the derivative from scipy
from scipy.optimize import approx_fprime

# %%
# define the function
def my_function(x):
    return x[0]**2 + x[0] + 1   # approx_fprime expects array input

# point where we compute derivative
x0 = np.array([2.0])

# step size
epsilon = np.sqrt(np.finfo(float).eps)

# compute derivative
grad = approx_fprime(x0, my_function, epsilon)

print(grad[0])
# Out:
# 5.0

# %%
from scipy.misc import derivative

# %% [markdown]
# #### Function: `f(x) = x**2 + x + 1`
# #### Derivate:  `f'(x) = 2*x + 1`
# #### Solution:  `f'(2) = 2*2 + 1 = 5`
#
# ---
#
# ***Now, calculate the second derivative***
#
# ---

# %%
derivative(func=my_function,x0=2,n=2)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_17772\564623337.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(func=my_function,x0=2,n=2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 derivative(func=my_function,x0=2,n=2)
#
# File F:\ShounakInstall\anaconda3\lib\site-packages\scipy\_lib\deprecation.py:20, in _deprecated.<locals>.wrap.<locals>.call(*args, **kwargs)
#      16 @functools.wraps(fun)
#      17 def call(*args, **kwargs):
#      18     warnings.warn(msg, category=DeprecationWarning,
#      19                   stacklevel=stacklevel)
# ---> 20     return fun(*args, **kwargs)
#
# File F:\ShounakInstall\anaconda3\lib\site-packages\scipy\misc\_common.py:126, in derivative(func, x0, dx, n, args, order)
#      79 @_deprecated(msg="scipy.misc.derivative is deprecated in "
#      80                  "SciPy v1.10.0; and will be completely removed in "
#      81                  "SciPy v1.12.0. You may consider using "
#      82                  "findiff: https://github.com/maroba/findiff or "
#      83                  "numdifftools: https://github.com/pbrod/numdifftools")
#      84 def derivative(func, x0, dx=1.0, n=1, args=(), order=3):
#      85     """
#      86     Find the nth derivative of a function at a point.
#      87
#    (...)
#     124
#     125     """
# --> 126     return _derivative(func, x0, dx, n, args, order)
#
# File F:\ShounakInstall\anaconda3\lib\site-packages\scipy\_lib\_finite_differences.py:144, in _derivative(func, x0, dx, n, args, order)
#     142 ho = order >> 1
#     143 for k in range(order):
# --> 144     val += weights[k] * func(x0 + (k - ho) * dx, *args)
#     145 return val / prod((dx,) * n, axis=0)
#
# Cell In[14], line 3, in my_function(x)
#       2 def my_function(x):
# ----> 3     return x[0]**2 + x[0] + 1
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# ---
#
# #### `PERMUTATION AND COMBINATIONS`
#
# ---

# %%
# COMBINATIONS
from scipy.special import comb

# total number of combinations from 4 different values taken 2 at a time
# Value of 4C2
com = comb(4, 2)

print(com)

# %%
# PERMUTATIONS: Value of 4P2
from scipy.special import perm
per = perm(4, 2)

print(per)

# %% [markdown]
# ---
#
#
# #### `LINEAR ALGEBRA`
#
#
#
# ---

# %%
# import linear algebra module and numpy
from scipy import linalg
import numpy as np

# %%
# square matrix
matrix = np.array([[1, 5, 2],
                   [3, 2, 1],
                   [1, 2, 1]])

# %%
matrix

# %%
# pass values to det() function
linalg.det(matrix)

# %%
# inverse of a matrix
linalg.inv(matrix)

# %% [markdown]
# ***Learn more about SciPy here: https://docs.scipy.org/doc/***
#
# ---
